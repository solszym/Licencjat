# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score


pd.set_option('display.max_rows', 500)
df = pd.read_excel('final_dataset_20-21.xlsx')
df.rename(columns=lambda x: x.replace(" (20/21)", ""), inplace=True)

df['Contract Years Left'] = pd.to_numeric(df['Contract Years Left'], errors='coerce')
df['Value'] = df['Value'] / 1000000

df_numeric = df.select_dtypes(include=[np.number])
df_numeric = df_numeric.dropna()
correlation_matrix = df_numeric.corr()
value_correlations = correlation_matrix['Value'].drop('Value', axis=0).sort_values()


print(value_correlations)
# Out:
# Age                                                                  -0.223886
# Goal Saving Blocks                                                   -0.054364
# Avg Shot Distance (yds)                                              -0.051458
# % Aerial Duels Won                                                   -0.047926
# % of Dribblers Tackled                                               -0.045539
# Total Clearances                                                     -0.027663
# Penalties Conceded                                                   -0.021307
# 2nd Yellow Cards                                                     -0.004800
# Red Cards                                                            -0.001868
# Mistakes leading to Opponent Shots                                    0.006684
# Tackles in Defensive 3rd                                              0.010761
# Own Goals                                                             0.013262
# Shots on Target%                                                      0.022635
# Total Shots Blocked                                                   0.024606
# % of Times Successfully Received Pass                                 0.025292
# Dribble Success %                                                     0.029929
# Number of Presses in Defensive Third                                  0.033525
# Yellow Cards                                                          0.038818
# Aerial Duel Won                                                       0.052251
# Touches in Defensive Penalty Box                                      0.058853
# Number of Dribblers Tackled                                           0.075654
# Goals/Shots on Target                                                 0.077049
# Goals/Shots                                                           0.077394
# Aerial Duel Lost                                                      0.078435
# Successful Pressure %                                                 0.078694
# Touches in Defensive 3rd                                              0.082048
# Completed Crosses that enter Penalty Box                              0.090898
# Non-Penalty xG/Shots                                                  0.091195
# Total Interceptions                                                   0.094294
# Interceptions                                                         0.094294
# Set-Piece Leading to Goals                                            0.107679
# Non-Penalty Goals Scored minus Non-Penalty xG                         0.112528
# Total Players Tackled + Total Interceptions                           0.113907
# Total Number of Players Tackled                                       0.115817
# Defensive Actions Leading to Goals                                    0.119736
# Times Dribbled Past + Total Tackles                                   0.122905
# Total Defensive Blocks                                                0.126451
# Goals Scored minus xG                                                 0.136024
# Number of Times Dribbled Past                                         0.136342
# Total Tackles Won                                                     0.139804
# Set-Piece Leading to Shot Attempt                                     0.141884
# Times blocked a Pass                                                  0.145018
# Pass Completion % (Short Passes)                                      0.148015
# Fouls Committed                                                       0.148071
# Tackles in Midfield 3rd                                               0.151678
# Pass Completion % (Medium Passes)                                     0.154445
# Assist minus xG Assisted                                              0.160829
# Crosses                                                               0.168061
# Pass Completion % (Long Passes)                                       0.170831
# Passes Attempted (Long Passes)                                        0.180640
# Total Loose Balls Recovered                                           0.190544
# Number of Presses in Midfield Third                                   0.200752
# Freekick Shots                                                        0.201565
# Offsides                                                              0.202092
# Defensive Actions Leading to Shot Attempt                             0.202500
# Pass Completion % (All pass-types)                                    0.203016
# Passes Completed (Long Passes)                                        0.205525
# Total Distance of Completed Progressive Passes (All Pass-types)       0.206174
# Penalty Kicks Won                                                     0.230712
# Number of Pressing Actions                                            0.240689
# Fouls Drawn Leading to Goals                                          0.241830
# Ast/90                                                                0.251455
# Penalties Attempted                                                   0.257199
# Shots on Target/90                                                    0.258353
# Shots Leading to Goals                                                0.259236
# Penalties Scored                                                      0.262771
# Shots/90                                                              0.262776
# Times Squad gained Possession within 5 seconds of Pressing Actions    0.263639
# MP                                                                    0.265134
# xA/90                                                                 0.268532
# Non-Penalty Goals/90                                                  0.269410
# Tackles in Attacking 3rd                                              0.273146
# Passes Completed (Medium Passes)                                      0.274456
# Non-Penalty xG/90                                                     0.274912
# Passes Attempted (Medium Passes)                                      0.277383
# Fouls Drawn                                                           0.279677
# Total Failed Attempts at Controlling Ball                             0.282273
# xG/90                                                                 0.288976
# Gls/90                                                                0.290619
# Shot-Creating Actions/90                                              0.292027
# Total Distance of Completed Passes (All Pass-types)                   0.293019
# Fouls Drawn Leading to Shot Attempt                                   0.305764
# Contract Years Left                                                   0.310461
# Total Nutmegs                                                         0.312321
# Starts                                                                0.312814
# Dribbles Leading to Goals                                             0.313648
# Total Mins/90                                                         0.318273
# Min                                                                   0.318373
# Completed passes that enter Final 3rd                                 0.318760
# Goal Creating Actions/90                                              0.319561
# (Gls+Ast-Scored Penalties)/90                                         0.320339
# Touches in Midfield 3rd                                               0.321365
# (Non-Penalty xG+xA)/90                                                0.323277
# Number of Times Tackled when Dribbling                                0.325979
# (xG+xA)/90                                                            0.330073
# (G+A)/90                                                              0.333142
# Number of Presses in Attacking Third                                  0.337770
# Passes Attempted (All pass-types)                                     0.343376
# Passes Completed (All pass-types)                                     0.346957
# Total Completed Progressive Passes                                    0.359933
# Touches                                                               0.361441
# Shots Leading to Shot Attempt                                         0.365633
# Dribbles Leading to Shot Attempt                                      0.369965
# Touches in Open-play                                                  0.376596
# Total no. of Players Dribbles Past                                    0.380625
# Total Successful Dribbles                                             0.384098
# Total Attempted Dribbles                                              0.387173
# Progressive Passes Received                                           0.411780
# Completed passes that enter Penalty Box                               0.416727
# Non-Penalty Goals                                                     0.417712
# Passes Completed (Short Passes)                                       0.420967
# Gls                                                                   0.424453
# Total Distance Carried the Ball                                       0.425018
# Total Distance Carried the Ball in Forward Direction                  0.426103
# Passes Attempted (Short Passes)                                       0.427329
# Total Assists                                                         0.429790
# Ast                                                                   0.429790
# xG                                                                    0.431499
# Non-Penalty xG                                                        0.434428
# Carries into Final Third                                              0.435672
# Total Carries                                                         0.437344
# xG Assisted                                                           0.440773
# xA                                                                    0.440773
# Total Shots on Target                                                 0.441015
# Number of Times Received Pass                                         0.444048
# Total Shots                                                           0.451431
# Carries into Attacking Penalty Box                                    0.462730
# Touches in Attacking 3rd                                              0.471426
# Shot-Creating Actions                                                 0.472070
# Touches in Attacking Penalty Box                                      0.478788
# Passes Leading to Shot Attempt                                        0.491146
# Non-penalty xG+ xA                                                    0.493304
# Number of Times Player was Pass Target                                0.494931
# Passes Leading to Goals                                               0.497123
# Goal Creating Actions                                                 0.505773
# Total Carries in Forward Direction                                    0.510385
# Name: Value, dtype: float64

# %%
X = df_numeric.drop('Value', axis=1)
y = df_numeric['Value']

sorted_features = value_correlations.index.tolist()
r2_scores = []

for i in range(1, len(sorted_features) + 1):
    selected_features = sorted_features[:i]
    X_selected = X[selected_features]
    
    X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=50)
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    r2 = r2_score(y_test, y_pred)
    r2_scores.append(r2)


for i, score in enumerate(r2_scores, 1):
    print(f'Liczba atrybutów: {i}, R^2: {score:.4f}')
# Out:
# Liczba atrybutów: 1, R^2: -0.0415
# Liczba atrybutów: 2, R^2: -0.0415
# Liczba atrybutów: 3, R^2: -0.0357
# Liczba atrybutów: 4, R^2: -0.0345
# Liczba atrybutów: 5, R^2: -0.0303
# Liczba atrybutów: 6, R^2: -0.0288
# Liczba atrybutów: 7, R^2: -0.0301
# Liczba atrybutów: 8, R^2: -0.0303
# Liczba atrybutów: 9, R^2: -0.0299
# Liczba atrybutów: 10, R^2: -0.0298
# Liczba atrybutów: 11, R^2: -0.0375
# Liczba atrybutów: 12, R^2: -0.0372
# Liczba atrybutów: 13, R^2: -0.0381
# Liczba atrybutów: 14, R^2: -0.0307
# Liczba atrybutów: 15, R^2: -0.0157
# Liczba atrybutów: 16, R^2: -0.0187
# Liczba atrybutów: 17, R^2: -0.0160
# Liczba atrybutów: 18, R^2: -0.0197
# Liczba atrybutów: 19, R^2: 0.0064
# Liczba atrybutów: 20, R^2: 0.0249
# Liczba atrybutów: 21, R^2: 0.0632
# Liczba atrybutów: 22, R^2: 0.0633
# Liczba atrybutów: 23, R^2: 0.0630
# Liczba atrybutów: 24, R^2: 0.0658
# Liczba atrybutów: 25, R^2: 0.0739
# Liczba atrybutów: 26, R^2: 0.1035
# Liczba atrybutów: 27, R^2: 0.1239
# Liczba atrybutów: 28, R^2: 0.1300
# Liczba atrybutów: 29, R^2: 0.1379
# Liczba atrybutów: 30, R^2: 0.1379
# Liczba atrybutów: 31, R^2: 0.1421
# Liczba atrybutów: 32, R^2: 0.1583
# Liczba atrybutów: 33, R^2: 0.1829
# Liczba atrybutów: 34, R^2: 0.1829
# Liczba atrybutów: 35, R^2: 0.1790
# Liczba atrybutów: 36, R^2: 0.1742
# Liczba atrybutów: 37, R^2: 0.1846
# Liczba atrybutów: 38, R^2: 0.2030
# Liczba atrybutów: 39, R^2: 0.2030
# Liczba atrybutów: 40, R^2: 0.2039
# Liczba atrybutów: 41, R^2: 0.2185
# Liczba atrybutów: 42, R^2: 0.2185
# Liczba atrybutów: 43, R^2: 0.2307
# Liczba atrybutów: 44, R^2: 0.2324
# Liczba atrybutów: 45, R^2: 0.2520
# Liczba atrybutów: 46, R^2: 0.2569
# Liczba atrybutów: 47, R^2: 0.2682
# Liczba atrybutów: 48, R^2: 0.2828
# Liczba atrybutów: 49, R^2: 0.2998
# Liczba atrybutów: 50, R^2: 0.3064
# Liczba atrybutów: 51, R^2: 0.3028
# Liczba atrybutów: 52, R^2: 0.3028
# Liczba atrybutów: 53, R^2: 0.3407
# Liczba atrybutów: 54, R^2: 0.3243
# Liczba atrybutów: 55, R^2: 0.3243
# Liczba atrybutów: 56, R^2: 0.3408
# Liczba atrybutów: 57, R^2: 0.3460
# Liczba atrybutów: 58, R^2: 0.3786
# Liczba atrybutów: 59, R^2: 0.3624
# Liczba atrybutów: 60, R^2: 0.3850
# Liczba atrybutów: 61, R^2: 0.3827
# Liczba atrybutów: 62, R^2: 0.3916
# Liczba atrybutów: 63, R^2: 0.4038
# Liczba atrybutów: 64, R^2: 0.4162
# Liczba atrybutów: 65, R^2: 0.4099
# Liczba atrybutów: 66, R^2: 0.4083
# Liczba atrybutów: 67, R^2: 0.4063
# Liczba atrybutów: 68, R^2: 0.4097
# Liczba atrybutów: 69, R^2: 0.4155
# Liczba atrybutów: 70, R^2: 0.4206
# Liczba atrybutów: 71, R^2: 0.4177
# Liczba atrybutów: 72, R^2: 0.4177
# Liczba atrybutów: 73, R^2: 0.4340
# Liczba atrybutów: 74, R^2: 0.4462
# Liczba atrybutów: 75, R^2: 0.4525
# Liczba atrybutów: 76, R^2: 0.4591
# Liczba atrybutów: 77, R^2: 0.4589
# Liczba atrybutów: 78, R^2: 0.4568
# Liczba atrybutów: 79, R^2: 0.4557
# Liczba atrybutów: 80, R^2: 0.4514
# Liczba atrybutów: 81, R^2: 0.4762
# Liczba atrybutów: 82, R^2: 0.4800
# Liczba atrybutów: 83, R^2: 0.4889
# Liczba atrybutów: 84, R^2: 0.4951
# Liczba atrybutów: 85, R^2: 0.4940
# Liczba atrybutów: 86, R^2: 0.4921
# Liczba atrybutów: 87, R^2: 0.4907
# Liczba atrybutów: 88, R^2: 0.4960
# Liczba atrybutów: 89, R^2: 0.4950
# Liczba atrybutów: 90, R^2: 0.4956
# Liczba atrybutów: 91, R^2: 0.4980
# Liczba atrybutów: 92, R^2: 0.4920
# Liczba atrybutów: 93, R^2: 0.4917
# Liczba atrybutów: 94, R^2: 0.4965
# Liczba atrybutów: 95, R^2: 0.4955
# Liczba atrybutów: 96, R^2: 0.4951
# Liczba atrybutów: 97, R^2: 0.4951
# Liczba atrybutów: 98, R^2: 0.4957
# Liczba atrybutów: 99, R^2: 0.4961
# Liczba atrybutów: 100, R^2: 0.4951
# Liczba atrybutów: 101, R^2: 0.5070
# Liczba atrybutów: 102, R^2: 0.5070
# Liczba atrybutów: 103, R^2: 0.5049
# Liczba atrybutów: 104, R^2: 0.5091
# Liczba atrybutów: 105, R^2: 0.5058
# Liczba atrybutów: 106, R^2: 0.5043
# Liczba atrybutów: 107, R^2: 0.5030
# Liczba atrybutów: 108, R^2: 0.5009
# Liczba atrybutów: 109, R^2: 0.5057
# Liczba atrybutów: 110, R^2: 0.5043
# Liczba atrybutów: 111, R^2: 0.5094
# Liczba atrybutów: 112, R^2: 0.5094
# Liczba atrybutów: 113, R^2: 0.5200
# Liczba atrybutów: 114, R^2: 0.5204
# Liczba atrybutów: 115, R^2: 0.5223
# Liczba atrybutów: 116, R^2: 0.5289
# Liczba atrybutów: 117, R^2: 0.5289
# Liczba atrybutów: 118, R^2: 0.5289
# Liczba atrybutów: 119, R^2: 0.5289
# Liczba atrybutów: 120, R^2: 0.5293
# Liczba atrybutów: 121, R^2: 0.5310
# Liczba atrybutów: 122, R^2: 0.5310
# Liczba atrybutów: 123, R^2: 0.5310
# Liczba atrybutów: 124, R^2: 0.5307
# Liczba atrybutów: 125, R^2: 0.5328
# Liczba atrybutów: 126, R^2: 0.5346
# Liczba atrybutów: 127, R^2: 0.5306
# Liczba atrybutów: 128, R^2: 0.5304
# Liczba atrybutów: 129, R^2: 0.5289
# Liczba atrybutów: 130, R^2: 0.5291
# Liczba atrybutów: 131, R^2: 0.5291
# Liczba atrybutów: 132, R^2: 0.5237
# Liczba atrybutów: 133, R^2: 0.5360
# Liczba atrybutów: 134, R^2: 0.5283
# Liczba atrybutów: 135, R^2: 0.5283
# Liczba atrybutów: 136, R^2: 0.5280
